# %%
# -*- coding: utf-8 -*-
"""
Batch Inference Script for DeepJSCC
"""
import os
import glob
import torch
from PIL import Image
from torchvision import transforms

from model import DeepJSCC, ratio2filtersize
from utils import image_normalization

# -------- CONFIGURATION --------
INPUT_DIR = '/home/MATLAB_DATA/TiNguyen/Sentry_Data/test'       # Folder with input images
OUTPUT_DIR = '/home/MATLAB_DATA/TiNguyen/Sentry_Data/test_snr13_ratio112'  # Folder to save outputs
DEVICE = 'cuda:0' if torch.cuda.is_available() else 'cpu'

# Match your training configuration
DATASET = 'imagenet'
SNR = 13.0
RATIO = 1 / 12
CHANNEL_TYPE = 'AWGN'
IMAGE_SIZE = (64, 64)


# -------- Auto Checkpoint Finder --------
def auto_find_checkpoint(dataset, c, snr, ratio, channel, base_dir='./out/checkpoints'):
    prefix = f"{dataset.upper()}_{c}_{snr}_{ratio:.2f}_{channel}_"
    candidates = [
        os.path.join(base_dir, d)
        for d in os.listdir(base_dir)
        if os.path.isdir(os.path.join(base_dir, d)) and d.startswith(prefix)
    ]
    if not candidates:
        raise FileNotFoundError(f"No checkpoint directories found with prefix: {prefix}")
    latest_dir = max(candidates, key=os.path.getmtime)
    ckpts = glob.glob(os.path.join(latest_dir, 'epoch_*.pth'))
    if not ckpts:
        raise FileNotFoundError(f"No checkpoint files in: {latest_dir}")
    latest_ckpt = sorted(ckpts, key=os.path.getmtime)[-1]
    print(f"✅ Found checkpoint: {latest_ckpt}")
    return latest_ckpt


# -------- Image Processing --------
def load_image(image_path, image_size):
    transform = transforms.Compose([
        transforms.Resize(image_size),
        transforms.ToTensor(),
    ])
    img = Image.open(image_path).convert("RGB")
    img_tensor = transform(img).unsqueeze(0)
    return img_tensor


# -------- Model Loader --------
def load_model(checkpoint_path, snr, ratio, channel_type, image_size, device):
    dummy_img = torch.randn(3, *image_size)
    c = ratio2filtersize(dummy_img, ratio)
    print(f"Loading model with inner channel c={c}")

    model = DeepJSCC(c=c, snr=snr, channel_type=channel_type)
    model.load_state_dict(torch.load(checkpoint_path, map_location=device))
    model.to(device)
    model.eval()
    return model


# -------- Inference Function --------
def run_inference(model, image_tensor, device):
    image_tensor = image_tensor.to(device)
    with torch.no_grad():
        output = model(image_tensor)
        output = image_normalization('denormalization')(output)
    return output.squeeze(0).cpu()


# -------- Batch Evaluation --------
def process_folder(input_dir, output_dir, model, image_size, device):
    os.makedirs(output_dir, exist_ok=True)

    # Recursively find all image files (supports jpg, png, jpeg)
    image_paths = sorted(
        glob.glob(os.path.join(input_dir, '**', '*.*'), recursive=True)
    )
    image_paths = [
        p for p in image_paths if p.lower().endswith(('.jpg', '.jpeg', '.png'))
    ]

    if not image_paths:
        print(f"No image files found in {input_dir}")
        return

    for img_path in image_paths:
        try:
            img_tensor = load_image(img_path, image_size)
            output_tensor = run_inference(model, img_tensor, device)
            output_tensor = output_tensor/255

            # Create subfolder in output dir if necessary
            relative_path = os.path.relpath(img_path, input_dir)
            save_path = os.path.join(output_dir, relative_path)
            os.makedirs(os.path.dirname(save_path), exist_ok=True)

            out_img = transforms.ToPILImage()(output_tensor.clamp(0, 1))
            out_img.save(save_path)
            print(f"✓ Processed: {relative_path}")
        except Exception as e:
            print(f"⚠️ Failed on {img_path}: {e}")




# -------- Main --------
def main():
    print("🚀 Starting batch inference...")

    dummy_img = torch.randn(3, *IMAGE_SIZE)
    c = ratio2filtersize(dummy_img, RATIO)
    checkpoint_path = auto_find_checkpoint(DATASET, c, SNR, RATIO, CHANNEL_TYPE)

    model = load_model(checkpoint_path, SNR, RATIO, CHANNEL_TYPE, IMAGE_SIZE, DEVICE)
    process_folder(INPUT_DIR, OUTPUT_DIR, model, IMAGE_SIZE, DEVICE)

    print("✅ All images processed.")


if __name__ == "__main__":
    main()
# Out:
# 🚀 Starting batch inference...
# ✅ Found checkpoint: ./out/checkpoints/IMAGENET_4_13.0_0.08_AWGN_19h20m35s_on_Jul_15_2025/epoch_499.pth
# Loading model with inner channel c=4
# ✓ Processed: AnnualCrop/AnnualCrop_2111.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2112.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2113.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2114.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2115.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2116.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2117.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2118.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2119.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2120.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2121.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2122.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2123.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2124.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2125.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2126.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2127.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2128.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2129.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2130.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2131.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2132.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2133.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2134.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2135.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2136.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2137.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2138.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2139.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2140.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2141.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2142.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2143.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2144.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2145.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2146.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2147.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2148.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2149.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2150.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2151.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2152.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2153.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2154.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2155.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2156.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2157.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2158.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2159.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2160.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2161.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2162.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2163.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2164.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2165.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2166.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2167.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2168.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2169.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2170.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2171.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2172.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2173.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2174.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2175.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2176.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2177.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2178.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2179.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2180.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2181.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2182.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2183.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2184.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2185.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2186.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2187.jpg
# /tmp/ipykernel_3861733/1938150871.py:64: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load(checkpoint_path, map_location=device))
# ✓ Processed: AnnualCrop/AnnualCrop_2188.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2189.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2190.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2191.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2192.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2193.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2194.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2195.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2196.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2197.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2198.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2199.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2200.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2201.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2202.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2203.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2204.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2205.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2206.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2207.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2208.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2209.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2210.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2211.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2212.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2213.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2214.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2215.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2216.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2217.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2218.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2219.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2220.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2221.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2222.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2223.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2224.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2225.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2226.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2227.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2228.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2229.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2230.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2231.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2232.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2233.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2234.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2235.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2236.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2237.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2238.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2239.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2240.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2241.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2242.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2243.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2244.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2245.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2246.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2247.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2248.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2249.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2250.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2251.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2252.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2253.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2254.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2255.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2256.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2257.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2258.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2259.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2260.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2261.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2262.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2263.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2264.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2265.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2266.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2267.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2268.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2269.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2270.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2271.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2272.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2273.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2274.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2275.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2276.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2277.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2278.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2279.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2280.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2281.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2282.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2283.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2284.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2285.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2286.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2287.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2288.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2289.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2290.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2291.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2292.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2293.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2294.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2295.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2296.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2297.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2298.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2299.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2300.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2301.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2302.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2303.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2304.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2305.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2306.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2307.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2308.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2309.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2310.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2311.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2312.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2313.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2314.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2315.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2316.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2317.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2318.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2319.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2320.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2321.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2322.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2323.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2324.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2325.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2326.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2327.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2328.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2329.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2330.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2331.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2332.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2333.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2334.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2335.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2336.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2337.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2338.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2339.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2340.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2341.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2342.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2343.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2344.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2345.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2346.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2347.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2348.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2349.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2350.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2351.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2352.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2353.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2354.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2355.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2356.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2357.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2358.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2359.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2360.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2361.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2362.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2363.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2364.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2365.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2366.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2367.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2368.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2369.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2370.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2371.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2372.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2373.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2374.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2375.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2376.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2377.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2378.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2379.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2380.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2381.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2382.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2383.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2384.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2385.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2386.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2387.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2388.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2389.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2390.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2391.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2392.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2393.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2394.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2395.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2396.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2397.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2398.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2399.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2400.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2401.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2402.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2403.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2404.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2405.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2406.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2407.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2408.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2409.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2410.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2411.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2412.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2413.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2414.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2415.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2416.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2417.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2418.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2419.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2420.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2421.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2422.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2423.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2424.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2425.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2426.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2427.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2428.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2429.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2430.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2431.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2432.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2433.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2434.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2435.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2436.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2437.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2438.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2439.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2440.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2441.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2442.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2443.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2444.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2445.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2446.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2447.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2448.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2449.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2450.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2451.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2452.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2453.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2454.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2455.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2456.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2457.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2458.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2459.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2460.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2461.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2462.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2463.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2464.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2465.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2466.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2467.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2468.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2469.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2470.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2471.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2472.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2473.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2474.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2475.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2476.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2477.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2478.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2479.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2480.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2481.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2482.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2483.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2484.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2485.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2486.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2487.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2488.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2489.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2490.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2491.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2492.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2493.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2494.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2495.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2496.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2497.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2498.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2499.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2500.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2501.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2502.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2503.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2504.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2505.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2506.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2507.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2508.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2509.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2510.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2511.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2512.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2513.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2514.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2515.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2516.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2517.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2518.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2519.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2520.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2521.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2522.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2523.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2524.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2525.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2526.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2527.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2528.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2529.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2530.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2531.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2532.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2533.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2534.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2535.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2536.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2537.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2538.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2539.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2540.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2541.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2542.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2543.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2544.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2545.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2546.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2547.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2548.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2549.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2550.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2551.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2552.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2553.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2554.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2555.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2556.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2557.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2558.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2559.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2560.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2561.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2562.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2563.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2564.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2565.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2566.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2567.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2568.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2569.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2570.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2571.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2572.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2573.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2574.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2575.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2576.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2577.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2578.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2579.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2580.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2581.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2582.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2583.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2584.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2585.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2586.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2587.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2588.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2589.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2590.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2591.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2592.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2593.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2594.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2595.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2596.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2597.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2598.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2599.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2600.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2601.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2602.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2603.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2604.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2605.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2606.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2607.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2608.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2609.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2610.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2611.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2612.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2613.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2614.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2615.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2616.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2617.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2618.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2619.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2620.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2621.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2622.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2623.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2624.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2625.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2626.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2627.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2628.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2629.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2630.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2631.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2632.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2633.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2634.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2635.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2636.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2637.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2638.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2639.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2640.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2641.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2642.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2643.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2644.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2645.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2646.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2647.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2648.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2649.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2650.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2651.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2652.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2653.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2654.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2655.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2656.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2657.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2658.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2659.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2660.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2661.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2662.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2663.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2664.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2665.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2666.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2667.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2668.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2669.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2670.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2671.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2672.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2673.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2674.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2675.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2676.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2677.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2678.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2679.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2680.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2681.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2682.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2683.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2684.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2685.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2686.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2687.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2688.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2689.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2690.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2691.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2692.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2693.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2694.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2695.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2696.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2697.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2698.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2699.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2700.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2701.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2702.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2703.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2704.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2705.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2706.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2707.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2708.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2709.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2710.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2711.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2712.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2713.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2714.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2715.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2716.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2717.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2718.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2719.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2720.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2721.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2722.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2723.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2724.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2725.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2726.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2727.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2728.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2729.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2730.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2731.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2732.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2733.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2734.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2735.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2736.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2737.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2738.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2739.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2740.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2741.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2742.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2743.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2744.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2745.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2746.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2747.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2748.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2749.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2750.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2751.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2752.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2753.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2754.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2755.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2756.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2757.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2758.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2759.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2760.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2761.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2762.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2763.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2764.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2765.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2766.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2767.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2768.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2769.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2770.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2771.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2772.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2773.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2774.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2775.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2776.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2777.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2778.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2779.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2780.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2781.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2782.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2783.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2784.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2785.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2786.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2787.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2788.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2789.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2790.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2791.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2792.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2793.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2794.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2795.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2796.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2797.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2798.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2799.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2800.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2801.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2802.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2803.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2804.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2805.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2806.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2807.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2808.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2809.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2810.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2811.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2812.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2813.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2814.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2815.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2816.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2817.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2818.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2819.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2820.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2821.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2822.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2823.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2824.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2825.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2826.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2827.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2828.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2829.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2830.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2831.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2832.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2833.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2834.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2835.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2836.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2837.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2838.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2839.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2840.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2841.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2842.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2843.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2844.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2845.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2846.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2847.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2848.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2849.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2850.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2851.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2852.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2853.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2854.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2855.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2856.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2857.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2858.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2859.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2860.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2861.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2862.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2863.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2864.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2865.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2866.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2867.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2868.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2869.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2870.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2871.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2872.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2873.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2874.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2875.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2876.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2877.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2878.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2879.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2880.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2881.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2882.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2883.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2884.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2885.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2886.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2887.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2888.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2889.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2890.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2891.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2892.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2893.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2894.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2895.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2896.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2897.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2898.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2899.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2900.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2901.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2902.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2903.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2904.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2905.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2906.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2907.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2908.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2909.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2910.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2911.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2912.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2913.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2914.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2915.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2916.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2917.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2918.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2919.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2920.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2921.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2922.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2923.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2924.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2925.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2926.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2927.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2928.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2929.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2930.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2931.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2932.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2933.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2934.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2935.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2936.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2937.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2938.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2939.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2940.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2941.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2942.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2943.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2944.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2945.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2946.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2947.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2948.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2949.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2950.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2951.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2952.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2953.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2954.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2955.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2956.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2957.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2958.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2959.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2960.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2961.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2962.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2963.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2964.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2965.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2966.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2967.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2968.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2969.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2970.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2971.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2972.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2973.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2974.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2975.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2976.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2977.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2978.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2979.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2980.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2981.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2982.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2983.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2984.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2985.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2986.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2987.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2988.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2989.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2990.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2991.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2992.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2993.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2994.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2995.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2996.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2997.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2998.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_2999.jpg
# ✓ Processed: AnnualCrop/AnnualCrop_3000.jpg
# ✓ Processed: Forest/Forest_2101.jpg
# ✓ Processed: Forest/Forest_2102.jpg
# ✓ Processed: Forest/Forest_2103.jpg
# ✓ Processed: Forest/Forest_2104.jpg
# ✓ Processed: Forest/Forest_2105.jpg
# ✓ Processed: Forest/Forest_2106.jpg
# ✓ Processed: Forest/Forest_2107.jpg
# ✓ Processed: Forest/Forest_2108.jpg
# ✓ Processed: Forest/Forest_2109.jpg
# ✓ Processed: Forest/Forest_2110.jpg
# ✓ Processed: Forest/Forest_2111.jpg
# ✓ Processed: Forest/Forest_2112.jpg
# ✓ Processed: Forest/Forest_2113.jpg
# ✓ Processed: Forest/Forest_2114.jpg
# ✓ Processed: Forest/Forest_2115.jpg
# ✓ Processed: Forest/Forest_2116.jpg
# ✓ Processed: Forest/Forest_2117.jpg
# ✓ Processed: Forest/Forest_2118.jpg
# ✓ Processed: Forest/Forest_2119.jpg
# ✓ Processed: Forest/Forest_2120.jpg
# ✓ Processed: Forest/Forest_2121.jpg
# ✓ Processed: Forest/Forest_2122.jpg
# ✓ Processed: Forest/Forest_2123.jpg
# ✓ Processed: Forest/Forest_2124.jpg
# ✓ Processed: Forest/Forest_2125.jpg
# ✓ Processed: Forest/Forest_2126.jpg
# ✓ Processed: Forest/Forest_2127.jpg
# ✓ Processed: Forest/Forest_2128.jpg
# ✓ Processed: Forest/Forest_2129.jpg
# ✓ Processed: Forest/Forest_2130.jpg
# ✓ Processed: Forest/Forest_2131.jpg
# ✓ Processed: Forest/Forest_2132.jpg
# ✓ Processed: Forest/Forest_2133.jpg
# ✓ Processed: Forest/Forest_2134.jpg
# ✓ Processed: Forest/Forest_2135.jpg
# ✓ Processed: Forest/Forest_2136.jpg
# ✓ Processed: Forest/Forest_2137.jpg
# ✓ Processed: Forest/Forest_2138.jpg
# ✓ Processed: Forest/Forest_2139.jpg
# ✓ Processed: Forest/Forest_2140.jpg
# ✓ Processed: Forest/Forest_2141.jpg
# ✓ Processed: Forest/Forest_2142.jpg
# ✓ Processed: Forest/Forest_2143.jpg
# ✓ Processed: Forest/Forest_2144.jpg
# ✓ Processed: Forest/Forest_2145.jpg
# ✓ Processed: Forest/Forest_2146.jpg
# ✓ Processed: Forest/Forest_2147.jpg
# ✓ Processed: Forest/Forest_2148.jpg
# ✓ Processed: Forest/Forest_2149.jpg
# ✓ Processed: Forest/Forest_2150.jpg
# ✓ Processed: Forest/Forest_2151.jpg
# ✓ Processed: Forest/Forest_2152.jpg
# ✓ Processed: Forest/Forest_2153.jpg
# ✓ Processed: Forest/Forest_2154.jpg
# ✓ Processed: Forest/Forest_2155.jpg
# ✓ Processed: Forest/Forest_2156.jpg
# ✓ Processed: Forest/Forest_2157.jpg
# ✓ Processed: Forest/Forest_2158.jpg
# ✓ Processed: Forest/Forest_2159.jpg
# ✓ Processed: Forest/Forest_2160.jpg
# ✓ Processed: Forest/Forest_2161.jpg
# ✓ Processed: Forest/Forest_2162.jpg
# ✓ Processed: Forest/Forest_2163.jpg
# ✓ Processed: Forest/Forest_2164.jpg
# ✓ Processed: Forest/Forest_2165.jpg
# ✓ Processed: Forest/Forest_2166.jpg
# ✓ Processed: Forest/Forest_2167.jpg
# ✓ Processed: Forest/Forest_2168.jpg
# ✓ Processed: Forest/Forest_2169.jpg
# ✓ Processed: Forest/Forest_2170.jpg
# ✓ Processed: Forest/Forest_2171.jpg
# ✓ Processed: Forest/Forest_2172.jpg
# ✓ Processed: Forest/Forest_2173.jpg
# ✓ Processed: Forest/Forest_2174.jpg
# ✓ Processed: Forest/Forest_2175.jpg
# ✓ Processed: Forest/Forest_2176.jpg
# ✓ Processed: Forest/Forest_2177.jpg
# ✓ Processed: Forest/Forest_2178.jpg
# ✓ Processed: Forest/Forest_2179.jpg
# ✓ Processed: Forest/Forest_2180.jpg
# ✓ Processed: Forest/Forest_2181.jpg
# ✓ Processed: Forest/Forest_2182.jpg
# ✓ Processed: Forest/Forest_2183.jpg
# ✓ Processed: Forest/Forest_2184.jpg
# ✓ Processed: Forest/Forest_2185.jpg
# ✓ Processed: Forest/Forest_2186.jpg
# ✓ Processed: Forest/Forest_2187.jpg
# ✓ Processed: Forest/Forest_2188.jpg
# ✓ Processed: Forest/Forest_2189.jpg
# ✓ Processed: Forest/Forest_2190.jpg
# ✓ Processed: Forest/Forest_2191.jpg
# ✓ Processed: Forest/Forest_2192.jpg
# ✓ Processed: Forest/Forest_2193.jpg
# ✓ Processed: Forest/Forest_2194.jpg
# ✓ Processed: Forest/Forest_2195.jpg
# ✓ Processed: Forest/Forest_2196.jpg
# ✓ Processed: Forest/Forest_2197.jpg
# ✓ Processed: Forest/Forest_2198.jpg
# ✓ Processed: Forest/Forest_2199.jpg
# ✓ Processed: Forest/Forest_2200.jpg
# ✓ Processed: Forest/Forest_2201.jpg
# ✓ Processed: Forest/Forest_2202.jpg
# ✓ Processed: Forest/Forest_2203.jpg
# ✓ Processed: Forest/Forest_2204.jpg
# ✓ Processed: Forest/Forest_2205.jpg
# ✓ Processed: Forest/Forest_2206.jpg
# ✓ Processed: Forest/Forest_2207.jpg
# ✓ Processed: Forest/Forest_2208.jpg
# ✓ Processed: Forest/Forest_2209.jpg
# ✓ Processed: Forest/Forest_2210.jpg
# ✓ Processed: Forest/Forest_2211.jpg
# ✓ Processed: Forest/Forest_2212.jpg
# ✓ Processed: Forest/Forest_2213.jpg
# ✓ Processed: Forest/Forest_2214.jpg
# ✓ Processed: Forest/Forest_2215.jpg
# ✓ Processed: Forest/Forest_2216.jpg
# ✓ Processed: Forest/Forest_2217.jpg
# ✓ Processed: Forest/Forest_2218.jpg
# ✓ Processed: Forest/Forest_2219.jpg
# ✓ Processed: Forest/Forest_2220.jpg
# ✓ Processed: Forest/Forest_2221.jpg
# ✓ Processed: Forest/Forest_2222.jpg
# ✓ Processed: Forest/Forest_2223.jpg
# ✓ Processed: Forest/Forest_2224.jpg
# ✓ Processed: Forest/Forest_2225.jpg
# ✓ Processed: Forest/Forest_2226.jpg
# ✓ Processed: Forest/Forest_2227.jpg
# ✓ Processed: Forest/Forest_2228.jpg
# ✓ Processed: Forest/Forest_2229.jpg
# ✓ Processed: Forest/Forest_2230.jpg
# ✓ Processed: Forest/Forest_2231.jpg
# ✓ Processed: Forest/Forest_2232.jpg
# ✓ Processed: Forest/Forest_2233.jpg
# ✓ Processed: Forest/Forest_2234.jpg
# ✓ Processed: Forest/Forest_2235.jpg
# ✓ Processed: Forest/Forest_2236.jpg
# ✓ Processed: Forest/Forest_2237.jpg
# ✓ Processed: Forest/Forest_2238.jpg
# ✓ Processed: Forest/Forest_2239.jpg
# ✓ Processed: Forest/Forest_2240.jpg
# ✓ Processed: Forest/Forest_2241.jpg
# ✓ Processed: Forest/Forest_2242.jpg
# ✓ Processed: Forest/Forest_2243.jpg
# ✓ Processed: Forest/Forest_2244.jpg
# ✓ Processed: Forest/Forest_2245.jpg
# ✓ Processed: Forest/Forest_2246.jpg
# ✓ Processed: Forest/Forest_2247.jpg
# ✓ Processed: Forest/Forest_2248.jpg
# ✓ Processed: Forest/Forest_2249.jpg
# ✓ Processed: Forest/Forest_2250.jpg
# ✓ Processed: Forest/Forest_2251.jpg
# ✓ Processed: Forest/Forest_2252.jpg
# ✓ Processed: Forest/Forest_2253.jpg
# ✓ Processed: Forest/Forest_2254.jpg
# ✓ Processed: Forest/Forest_2255.jpg
# ✓ Processed: Forest/Forest_2256.jpg
# ✓ Processed: Forest/Forest_2257.jpg
# ✓ Processed: Forest/Forest_2258.jpg
# ✓ Processed: Forest/Forest_2259.jpg
# ✓ Processed: Forest/Forest_2260.jpg
# ✓ Processed: Forest/Forest_2261.jpg
# ✓ Processed: Forest/Forest_2262.jpg
# ✓ Processed: Forest/Forest_2263.jpg
# ✓ Processed: Forest/Forest_2264.jpg
# ✓ Processed: Forest/Forest_2265.jpg
# ✓ Processed: Forest/Forest_2266.jpg
# ✓ Processed: Forest/Forest_2267.jpg
# ✓ Processed: Forest/Forest_2268.jpg
# ✓ Processed: Forest/Forest_2269.jpg
# ✓ Processed: Forest/Forest_2270.jpg
# ✓ Processed: Forest/Forest_2271.jpg
# ✓ Processed: Forest/Forest_2272.jpg
# ✓ Processed: Forest/Forest_2273.jpg
# ✓ Processed: Forest/Forest_2274.jpg
# ✓ Processed: Forest/Forest_2275.jpg
# ✓ Processed: Forest/Forest_2276.jpg
# ✓ Processed: Forest/Forest_2277.jpg
# ✓ Processed: Forest/Forest_2278.jpg
# ✓ Processed: Forest/Forest_2279.jpg
# ✓ Processed: Forest/Forest_2280.jpg
# ✓ Processed: Forest/Forest_2281.jpg
# ✓ Processed: Forest/Forest_2282.jpg
# ✓ Processed: Forest/Forest_2283.jpg
# ✓ Processed: Forest/Forest_2284.jpg
# ✓ Processed: Forest/Forest_2285.jpg
# ✓ Processed: Forest/Forest_2286.jpg
# ✓ Processed: Forest/Forest_2287.jpg
# ✓ Processed: Forest/Forest_2288.jpg
# ✓ Processed: Forest/Forest_2289.jpg
# ✓ Processed: Forest/Forest_2290.jpg
# ✓ Processed: Forest/Forest_2291.jpg
# ✓ Processed: Forest/Forest_2292.jpg
# ✓ Processed: Forest/Forest_2293.jpg
# ✓ Processed: Forest/Forest_2294.jpg
# ✓ Processed: Forest/Forest_2295.jpg
# ✓ Processed: Forest/Forest_2296.jpg
# ✓ Processed: Forest/Forest_2297.jpg
# ✓ Processed: Forest/Forest_2298.jpg
# ✓ Processed: Forest/Forest_2299.jpg
# ✓ Processed: Forest/Forest_2300.jpg
# ✓ Processed: Forest/Forest_2301.jpg
# ✓ Processed: Forest/Forest_2302.jpg
# ✓ Processed: Forest/Forest_2303.jpg
# ✓ Processed: Forest/Forest_2304.jpg
# ✓ Processed: Forest/Forest_2305.jpg
# ✓ Processed: Forest/Forest_2306.jpg
# ✓ Processed: Forest/Forest_2307.jpg
# ✓ Processed: Forest/Forest_2308.jpg
# ✓ Processed: Forest/Forest_2309.jpg
# ✓ Processed: Forest/Forest_2310.jpg
# ✓ Processed: Forest/Forest_2311.jpg
# ✓ Processed: Forest/Forest_2312.jpg
# ✓ Processed: Forest/Forest_2313.jpg
# ...
# ✓ Processed: SeaLake/SeaLake_2581.jpg
# ✓ Processed: SeaLake/SeaLake_2582.jpg
# ✓ Processed: SeaLake/SeaLake_2583.jpg
# ✓ Processed: SeaLake/SeaLake_2584.jpg
# ✓ Processed: SeaLake/SeaLake_2585.jpg
# ✓ Processed: SeaLake/SeaLake_2586.jpg
# ✓ Processed: SeaLake/SeaLake_2587.jpg
# ✓ Processed: SeaLake/SeaLake_2588.jpg
# ✓ Processed: SeaLake/SeaLake_2589.jpg
# ✓ Processed: SeaLake/SeaLake_2590.jpg
# ✓ Processed: SeaLake/SeaLake_2591.jpg
# ✓ Processed: SeaLake/SeaLake_2592.jpg
# ✓ Processed: SeaLake/SeaLake_2593.jpg
# ✓ Processed: SeaLake/SeaLake_2594.jpg
# ✓ Processed: SeaLake/SeaLake_2595.jpg
# ✓ Processed: SeaLake/SeaLake_2596.jpg
# ✓ Processed: SeaLake/SeaLake_2597.jpg
# ✓ Processed: SeaLake/SeaLake_2598.jpg
# ✓ Processed: SeaLake/SeaLake_2599.jpg
# ✓ Processed: SeaLake/SeaLake_2600.jpg
# ✓ Processed: SeaLake/SeaLake_2601.jpg
# ✓ Processed: SeaLake/SeaLake_2602.jpg
# ✓ Processed: SeaLake/SeaLake_2603.jpg
# ✓ Processed: SeaLake/SeaLake_2604.jpg
# ✓ Processed: SeaLake/SeaLake_2605.jpg
# ✓ Processed: SeaLake/SeaLake_2606.jpg
# ✓ Processed: SeaLake/SeaLake_2607.jpg
# ✓ Processed: SeaLake/SeaLake_2608.jpg
# ✓ Processed: SeaLake/SeaLake_2609.jpg
# ✓ Processed: SeaLake/SeaLake_2610.jpg
# ✓ Processed: SeaLake/SeaLake_2611.jpg
# ✓ Processed: SeaLake/SeaLake_2612.jpg
# ✓ Processed: SeaLake/SeaLake_2613.jpg
# ✓ Processed: SeaLake/SeaLake_2614.jpg
# ✓ Processed: SeaLake/SeaLake_2615.jpg
# ✓ Processed: SeaLake/SeaLake_2616.jpg
# ✓ Processed: SeaLake/SeaLake_2617.jpg
# ✓ Processed: SeaLake/SeaLake_2618.jpg
# ✓ Processed: SeaLake/SeaLake_2619.jpg
# ✓ Processed: SeaLake/SeaLake_2620.jpg
# ✓ Processed: SeaLake/SeaLake_2621.jpg
# ✓ Processed: SeaLake/SeaLake_2622.jpg
# ✓ Processed: SeaLake/SeaLake_2623.jpg
# ✓ Processed: SeaLake/SeaLake_2624.jpg
# ✓ Processed: SeaLake/SeaLake_2625.jpg
# ✓ Processed: SeaLake/SeaLake_2626.jpg
# ✓ Processed: SeaLake/SeaLake_2627.jpg
# ✓ Processed: SeaLake/SeaLake_2628.jpg
# ✓ Processed: SeaLake/SeaLake_2629.jpg
# ✓ Processed: SeaLake/SeaLake_2630.jpg
# ✓ Processed: SeaLake/SeaLake_2631.jpg
# ✓ Processed: SeaLake/SeaLake_2632.jpg
# ✓ Processed: SeaLake/SeaLake_2633.jpg
# ✓ Processed: SeaLake/SeaLake_2634.jpg
# ✓ Processed: SeaLake/SeaLake_2635.jpg
# ✓ Processed: SeaLake/SeaLake_2636.jpg
# ✓ Processed: SeaLake/SeaLake_2637.jpg
# ✓ Processed: SeaLake/SeaLake_2638.jpg
# ✓ Processed: SeaLake/SeaLake_2639.jpg
# ✓ Processed: SeaLake/SeaLake_2640.jpg
# ✓ Processed: SeaLake/SeaLake_2641.jpg
# ✓ Processed: SeaLake/SeaLake_2642.jpg
# ✓ Processed: SeaLake/SeaLake_2643.jpg
# ✓ Processed: SeaLake/SeaLake_2644.jpg
# ✓ Processed: SeaLake/SeaLake_2645.jpg
# ✓ Processed: SeaLake/SeaLake_2646.jpg
# ✓ Processed: SeaLake/SeaLake_2647.jpg
# ✓ Processed: SeaLake/SeaLake_2648.jpg
# ✓ Processed: SeaLake/SeaLake_2649.jpg
# ✓ Processed: SeaLake/SeaLake_2650.jpg
# ✓ Processed: SeaLake/SeaLake_2651.jpg
# ✓ Processed: SeaLake/SeaLake_2652.jpg
# ✓ Processed: SeaLake/SeaLake_2653.jpg
# ✓ Processed: SeaLake/SeaLake_2654.jpg
# ✓ Processed: SeaLake/SeaLake_2655.jpg
# ✓ Processed: SeaLake/SeaLake_2656.jpg
# ✓ Processed: SeaLake/SeaLake_2657.jpg
# ✓ Processed: SeaLake/SeaLake_2658.jpg
# ✓ Processed: SeaLake/SeaLake_2659.jpg
# ✓ Processed: SeaLake/SeaLake_2660.jpg
# ✓ Processed: SeaLake/SeaLake_2661.jpg
# ✓ Processed: SeaLake/SeaLake_2662.jpg
# ✓ Processed: SeaLake/SeaLake_2663.jpg
# ✓ Processed: SeaLake/SeaLake_2664.jpg
# ✓ Processed: SeaLake/SeaLake_2665.jpg
# ✓ Processed: SeaLake/SeaLake_2666.jpg
# ✓ Processed: SeaLake/SeaLake_2667.jpg
# ✓ Processed: SeaLake/SeaLake_2668.jpg
# ✓ Processed: SeaLake/SeaLake_2669.jpg
# ✓ Processed: SeaLake/SeaLake_2670.jpg
# ✓ Processed: SeaLake/SeaLake_2671.jpg
# ✓ Processed: SeaLake/SeaLake_2672.jpg
# ✓ Processed: SeaLake/SeaLake_2673.jpg
# ✓ Processed: SeaLake/SeaLake_2674.jpg
# ✓ Processed: SeaLake/SeaLake_2675.jpg
# ✓ Processed: SeaLake/SeaLake_2676.jpg
# ✓ Processed: SeaLake/SeaLake_2677.jpg
# ✓ Processed: SeaLake/SeaLake_2678.jpg
# ✓ Processed: SeaLake/SeaLake_2679.jpg
# ✓ Processed: SeaLake/SeaLake_2680.jpg
# ✓ Processed: SeaLake/SeaLake_2681.jpg
# ✓ Processed: SeaLake/SeaLake_2682.jpg
# ✓ Processed: SeaLake/SeaLake_2683.jpg
# ✓ Processed: SeaLake/SeaLake_2684.jpg
# ✓ Processed: SeaLake/SeaLake_2685.jpg
# ✓ Processed: SeaLake/SeaLake_2686.jpg
# ✓ Processed: SeaLake/SeaLake_2687.jpg
# ✓ Processed: SeaLake/SeaLake_2688.jpg
# ✓ Processed: SeaLake/SeaLake_2689.jpg
# ✓ Processed: SeaLake/SeaLake_2690.jpg
# ✓ Processed: SeaLake/SeaLake_2691.jpg
# ✓ Processed: SeaLake/SeaLake_2692.jpg
# ✓ Processed: SeaLake/SeaLake_2693.jpg
# ✓ Processed: SeaLake/SeaLake_2694.jpg
# ✓ Processed: SeaLake/SeaLake_2695.jpg
# ✓ Processed: SeaLake/SeaLake_2696.jpg
# ✓ Processed: SeaLake/SeaLake_2697.jpg
# ✓ Processed: SeaLake/SeaLake_2698.jpg
# ✓ Processed: SeaLake/SeaLake_2699.jpg
# ✓ Processed: SeaLake/SeaLake_2700.jpg
# ✓ Processed: SeaLake/SeaLake_2701.jpg
# ✓ Processed: SeaLake/SeaLake_2702.jpg
# ✓ Processed: SeaLake/SeaLake_2703.jpg
# ✓ Processed: SeaLake/SeaLake_2704.jpg
# ✓ Processed: SeaLake/SeaLake_2705.jpg
# ✓ Processed: SeaLake/SeaLake_2706.jpg
# ✓ Processed: SeaLake/SeaLake_2707.jpg
# ✓ Processed: SeaLake/SeaLake_2708.jpg
# ✓ Processed: SeaLake/SeaLake_2709.jpg
# ✓ Processed: SeaLake/SeaLake_2710.jpg
# ✓ Processed: SeaLake/SeaLake_2711.jpg
# ✓ Processed: SeaLake/SeaLake_2712.jpg
# ✓ Processed: SeaLake/SeaLake_2713.jpg
# ✓ Processed: SeaLake/SeaLake_2714.jpg
# ✓ Processed: SeaLake/SeaLake_2715.jpg
# ✓ Processed: SeaLake/SeaLake_2716.jpg
# ✓ Processed: SeaLake/SeaLake_2717.jpg
# ✓ Processed: SeaLake/SeaLake_2718.jpg
# ✓ Processed: SeaLake/SeaLake_2719.jpg
# ✓ Processed: SeaLake/SeaLake_2720.jpg
# ✓ Processed: SeaLake/SeaLake_2721.jpg
# ✓ Processed: SeaLake/SeaLake_2722.jpg
# ✓ Processed: SeaLake/SeaLake_2723.jpg
# ✓ Processed: SeaLake/SeaLake_2724.jpg
# ✓ Processed: SeaLake/SeaLake_2725.jpg
# ✓ Processed: SeaLake/SeaLake_2726.jpg
# ✓ Processed: SeaLake/SeaLake_2727.jpg
# ✓ Processed: SeaLake/SeaLake_2728.jpg
# ✓ Processed: SeaLake/SeaLake_2729.jpg
# ✓ Processed: SeaLake/SeaLake_2730.jpg
# ✓ Processed: SeaLake/SeaLake_2731.jpg
# ✓ Processed: SeaLake/SeaLake_2732.jpg
# ✓ Processed: SeaLake/SeaLake_2733.jpg
# ✓ Processed: SeaLake/SeaLake_2734.jpg
# ✓ Processed: SeaLake/SeaLake_2735.jpg
# ✓ Processed: SeaLake/SeaLake_2736.jpg
# ✓ Processed: SeaLake/SeaLake_2737.jpg
# ✓ Processed: SeaLake/SeaLake_2738.jpg
# ✓ Processed: SeaLake/SeaLake_2739.jpg
# ✓ Processed: SeaLake/SeaLake_2740.jpg
# ✓ Processed: SeaLake/SeaLake_2741.jpg
# ✓ Processed: SeaLake/SeaLake_2742.jpg
# ✓ Processed: SeaLake/SeaLake_2743.jpg
# ✓ Processed: SeaLake/SeaLake_2744.jpg
# ✓ Processed: SeaLake/SeaLake_2745.jpg
# ✓ Processed: SeaLake/SeaLake_2746.jpg
# ✓ Processed: SeaLake/SeaLake_2747.jpg
# ✓ Processed: SeaLake/SeaLake_2748.jpg
# ✓ Processed: SeaLake/SeaLake_2749.jpg
# ✓ Processed: SeaLake/SeaLake_2750.jpg
# ✓ Processed: SeaLake/SeaLake_2751.jpg
# ✓ Processed: SeaLake/SeaLake_2752.jpg
# ✓ Processed: SeaLake/SeaLake_2753.jpg
# ✓ Processed: SeaLake/SeaLake_2754.jpg
# ✓ Processed: SeaLake/SeaLake_2755.jpg
# ✓ Processed: SeaLake/SeaLake_2756.jpg
# ✓ Processed: SeaLake/SeaLake_2757.jpg
# ✓ Processed: SeaLake/SeaLake_2758.jpg
# ✓ Processed: SeaLake/SeaLake_2759.jpg
# ✓ Processed: SeaLake/SeaLake_2760.jpg
# ✓ Processed: SeaLake/SeaLake_2761.jpg
# ✓ Processed: SeaLake/SeaLake_2762.jpg
# ✓ Processed: SeaLake/SeaLake_2763.jpg
# ✓ Processed: SeaLake/SeaLake_2764.jpg
# ✓ Processed: SeaLake/SeaLake_2765.jpg
# ✓ Processed: SeaLake/SeaLake_2766.jpg
# ✓ Processed: SeaLake/SeaLake_2767.jpg
# ✓ Processed: SeaLake/SeaLake_2768.jpg
# ✓ Processed: SeaLake/SeaLake_2769.jpg
# ✓ Processed: SeaLake/SeaLake_2770.jpg
# ✓ Processed: SeaLake/SeaLake_2771.jpg
# ✓ Processed: SeaLake/SeaLake_2772.jpg
# ✓ Processed: SeaLake/SeaLake_2773.jpg
# ✓ Processed: SeaLake/SeaLake_2774.jpg
# ✓ Processed: SeaLake/SeaLake_2775.jpg
# ✓ Processed: SeaLake/SeaLake_2776.jpg
# ✓ Processed: SeaLake/SeaLake_2777.jpg
# ✓ Processed: SeaLake/SeaLake_2778.jpg
# ✓ Processed: SeaLake/SeaLake_2779.jpg
# ✓ Processed: SeaLake/SeaLake_2780.jpg
# ✓ Processed: SeaLake/SeaLake_2781.jpg
# ✓ Processed: SeaLake/SeaLake_2782.jpg
# ✓ Processed: SeaLake/SeaLake_2783.jpg
# ✓ Processed: SeaLake/SeaLake_2784.jpg
# ✓ Processed: SeaLake/SeaLake_2785.jpg
# ✓ Processed: SeaLake/SeaLake_2786.jpg
# ✓ Processed: SeaLake/SeaLake_2787.jpg
# ✓ Processed: SeaLake/SeaLake_2788.jpg
# ✓ Processed: SeaLake/SeaLake_2789.jpg
# ✓ Processed: SeaLake/SeaLake_2790.jpg
# ✓ Processed: SeaLake/SeaLake_2791.jpg
# ✓ Processed: SeaLake/SeaLake_2792.jpg
# ✓ Processed: SeaLake/SeaLake_2793.jpg
# ✓ Processed: SeaLake/SeaLake_2794.jpg
# ✓ Processed: SeaLake/SeaLake_2795.jpg
# ✓ Processed: SeaLake/SeaLake_2796.jpg
# ✓ Processed: SeaLake/SeaLake_2797.jpg
# ✓ Processed: SeaLake/SeaLake_2798.jpg
# ✓ Processed: SeaLake/SeaLake_2799.jpg
# ✓ Processed: SeaLake/SeaLake_2800.jpg
# ✓ Processed: SeaLake/SeaLake_2801.jpg
# ✓ Processed: SeaLake/SeaLake_2802.jpg
# ✓ Processed: SeaLake/SeaLake_2803.jpg
# ✓ Processed: SeaLake/SeaLake_2804.jpg
# ✓ Processed: SeaLake/SeaLake_2805.jpg
# ✓ Processed: SeaLake/SeaLake_2806.jpg
# ✓ Processed: SeaLake/SeaLake_2807.jpg
# ✓ Processed: SeaLake/SeaLake_2808.jpg
# ✓ Processed: SeaLake/SeaLake_2809.jpg
# ✓ Processed: SeaLake/SeaLake_2810.jpg
# ✓ Processed: SeaLake/SeaLake_2811.jpg
# ✓ Processed: SeaLake/SeaLake_2812.jpg
# ✓ Processed: SeaLake/SeaLake_2813.jpg
# ✓ Processed: SeaLake/SeaLake_2814.jpg
# ✓ Processed: SeaLake/SeaLake_2815.jpg
# ✓ Processed: SeaLake/SeaLake_2816.jpg
# ✓ Processed: SeaLake/SeaLake_2817.jpg
# ✓ Processed: SeaLake/SeaLake_2818.jpg
# ✓ Processed: SeaLake/SeaLake_2819.jpg
# ✓ Processed: SeaLake/SeaLake_2820.jpg
# ✓ Processed: SeaLake/SeaLake_2821.jpg
# ✓ Processed: SeaLake/SeaLake_2822.jpg
# ✓ Processed: SeaLake/SeaLake_2823.jpg
# ✓ Processed: SeaLake/SeaLake_2824.jpg
# ✓ Processed: SeaLake/SeaLake_2825.jpg
# ✓ Processed: SeaLake/SeaLake_2826.jpg
# ✓ Processed: SeaLake/SeaLake_2827.jpg
# ✓ Processed: SeaLake/SeaLake_2828.jpg
# ✓ Processed: SeaLake/SeaLake_2829.jpg
# ✓ Processed: SeaLake/SeaLake_2830.jpg
# ✓ Processed: SeaLake/SeaLake_2831.jpg
# ✓ Processed: SeaLake/SeaLake_2832.jpg
# ✓ Processed: SeaLake/SeaLake_2833.jpg
# ✓ Processed: SeaLake/SeaLake_2834.jpg
# ✓ Processed: SeaLake/SeaLake_2835.jpg
# ✓ Processed: SeaLake/SeaLake_2836.jpg
# ✓ Processed: SeaLake/SeaLake_2837.jpg
# ✓ Processed: SeaLake/SeaLake_2838.jpg
# ✓ Processed: SeaLake/SeaLake_2839.jpg
# ✓ Processed: SeaLake/SeaLake_2840.jpg
# ✓ Processed: SeaLake/SeaLake_2841.jpg
# ✓ Processed: SeaLake/SeaLake_2842.jpg
# ✓ Processed: SeaLake/SeaLake_2843.jpg
# ✓ Processed: SeaLake/SeaLake_2844.jpg
# ✓ Processed: SeaLake/SeaLake_2845.jpg
# ✓ Processed: SeaLake/SeaLake_2846.jpg
# ✓ Processed: SeaLake/SeaLake_2847.jpg
# ✓ Processed: SeaLake/SeaLake_2848.jpg
# ✓ Processed: SeaLake/SeaLake_2849.jpg
# ✓ Processed: SeaLake/SeaLake_2850.jpg
# ✓ Processed: SeaLake/SeaLake_2851.jpg
# ✓ Processed: SeaLake/SeaLake_2852.jpg
# ✓ Processed: SeaLake/SeaLake_2853.jpg
# ✓ Processed: SeaLake/SeaLake_2854.jpg
# ✓ Processed: SeaLake/SeaLake_2855.jpg
# ✓ Processed: SeaLake/SeaLake_2856.jpg
# ✓ Processed: SeaLake/SeaLake_2857.jpg
# ✓ Processed: SeaLake/SeaLake_2858.jpg
# ✓ Processed: SeaLake/SeaLake_2859.jpg
# ✓ Processed: SeaLake/SeaLake_2860.jpg
# ✓ Processed: SeaLake/SeaLake_2861.jpg
# ✓ Processed: SeaLake/SeaLake_2862.jpg
# ✓ Processed: SeaLake/SeaLake_2863.jpg
# ✓ Processed: SeaLake/SeaLake_2864.jpg
# ✓ Processed: SeaLake/SeaLake_2865.jpg
# ✓ Processed: SeaLake/SeaLake_2866.jpg
# ✓ Processed: SeaLake/SeaLake_2867.jpg
# ✓ Processed: SeaLake/SeaLake_2868.jpg
# ✓ Processed: SeaLake/SeaLake_2869.jpg
# ✓ Processed: SeaLake/SeaLake_2870.jpg
# ✓ Processed: SeaLake/SeaLake_2871.jpg
# ✓ Processed: SeaLake/SeaLake_2872.jpg
# ✓ Processed: SeaLake/SeaLake_2873.jpg
# ✓ Processed: SeaLake/SeaLake_2874.jpg
# ✓ Processed: SeaLake/SeaLake_2875.jpg
# ✓ Processed: SeaLake/SeaLake_2876.jpg
# ✓ Processed: SeaLake/SeaLake_2877.jpg
# ✓ Processed: SeaLake/SeaLake_2878.jpg
# ✓ Processed: SeaLake/SeaLake_2879.jpg
# ✓ Processed: SeaLake/SeaLake_2880.jpg
# ✓ Processed: SeaLake/SeaLake_2881.jpg
# ✓ Processed: SeaLake/SeaLake_2882.jpg
# ✓ Processed: SeaLake/SeaLake_2883.jpg
# ✓ Processed: SeaLake/SeaLake_2884.jpg
# ✓ Processed: SeaLake/SeaLake_2885.jpg
# ✓ Processed: SeaLake/SeaLake_2886.jpg
# ✓ Processed: SeaLake/SeaLake_2887.jpg
# ✓ Processed: SeaLake/SeaLake_2888.jpg
# ✓ Processed: SeaLake/SeaLake_2889.jpg
# ✓ Processed: SeaLake/SeaLake_2890.jpg
# ✓ Processed: SeaLake/SeaLake_2891.jpg
# ✓ Processed: SeaLake/SeaLake_2892.jpg
# ✓ Processed: SeaLake/SeaLake_2893.jpg
# ✓ Processed: SeaLake/SeaLake_2894.jpg
# ✓ Processed: SeaLake/SeaLake_2895.jpg
# ✓ Processed: SeaLake/SeaLake_2896.jpg
# ✓ Processed: SeaLake/SeaLake_2897.jpg
# ✓ Processed: SeaLake/SeaLake_2898.jpg
# ✓ Processed: SeaLake/SeaLake_2899.jpg
# ✓ Processed: SeaLake/SeaLake_2900.jpg
# ✓ Processed: SeaLake/SeaLake_2901.jpg
# ✓ Processed: SeaLake/SeaLake_2902.jpg
# ✓ Processed: SeaLake/SeaLake_2903.jpg
# ✓ Processed: SeaLake/SeaLake_2904.jpg
# ✓ Processed: SeaLake/SeaLake_2905.jpg
# ✓ Processed: SeaLake/SeaLake_2906.jpg
# ✓ Processed: SeaLake/SeaLake_2907.jpg
# ✓ Processed: SeaLake/SeaLake_2908.jpg
# ✓ Processed: SeaLake/SeaLake_2909.jpg
# ✓ Processed: SeaLake/SeaLake_2910.jpg
# ✓ Processed: SeaLake/SeaLake_2911.jpg
# ✓ Processed: SeaLake/SeaLake_2912.jpg
# ✓ Processed: SeaLake/SeaLake_2913.jpg
# ✓ Processed: SeaLake/SeaLake_2914.jpg
# ✓ Processed: SeaLake/SeaLake_2915.jpg
# ✓ Processed: SeaLake/SeaLake_2916.jpg
# ✓ Processed: SeaLake/SeaLake_2917.jpg
# ✓ Processed: SeaLake/SeaLake_2918.jpg
# ✓ Processed: SeaLake/SeaLake_2919.jpg
# ✓ Processed: SeaLake/SeaLake_2920.jpg
# ✓ Processed: SeaLake/SeaLake_2921.jpg
# ✓ Processed: SeaLake/SeaLake_2922.jpg
# ✓ Processed: SeaLake/SeaLake_2923.jpg
# ✓ Processed: SeaLake/SeaLake_2924.jpg
# ✓ Processed: SeaLake/SeaLake_2925.jpg
# ✓ Processed: SeaLake/SeaLake_2926.jpg
# ✓ Processed: SeaLake/SeaLake_2927.jpg
# ✓ Processed: SeaLake/SeaLake_2928.jpg
# ✓ Processed: SeaLake/SeaLake_2929.jpg
# ✓ Processed: SeaLake/SeaLake_2930.jpg
# ✓ Processed: SeaLake/SeaLake_2931.jpg
# ✓ Processed: SeaLake/SeaLake_2932.jpg
# ✓ Processed: SeaLake/SeaLake_2933.jpg
# ✓ Processed: SeaLake/SeaLake_2934.jpg
# ✓ Processed: SeaLake/SeaLake_2935.jpg
# ✓ Processed: SeaLake/SeaLake_2936.jpg
# ✓ Processed: SeaLake/SeaLake_2937.jpg
# ✓ Processed: SeaLake/SeaLake_2938.jpg
# ✓ Processed: SeaLake/SeaLake_2939.jpg
# ✓ Processed: SeaLake/SeaLake_2940.jpg
# ✓ Processed: SeaLake/SeaLake_2941.jpg
# ✓ Processed: SeaLake/SeaLake_2942.jpg
# ✓ Processed: SeaLake/SeaLake_2943.jpg
# ✓ Processed: SeaLake/SeaLake_2944.jpg
# ✓ Processed: SeaLake/SeaLake_2945.jpg
# ✓ Processed: SeaLake/SeaLake_2946.jpg
# ✓ Processed: SeaLake/SeaLake_2947.jpg
# ✓ Processed: SeaLake/SeaLake_2948.jpg
# ✓ Processed: SeaLake/SeaLake_2949.jpg
# ✓ Processed: SeaLake/SeaLake_2950.jpg
# ✓ Processed: SeaLake/SeaLake_2951.jpg
# ✓ Processed: SeaLake/SeaLake_2952.jpg
# ✓ Processed: SeaLake/SeaLake_2953.jpg
# ✓ Processed: SeaLake/SeaLake_2954.jpg
# ✓ Processed: SeaLake/SeaLake_2955.jpg
# ✓ Processed: SeaLake/SeaLake_2956.jpg
# ✓ Processed: SeaLake/SeaLake_2957.jpg
# ✓ Processed: SeaLake/SeaLake_2958.jpg
# ✓ Processed: SeaLake/SeaLake_2959.jpg
# ✓ Processed: SeaLake/SeaLake_2960.jpg
# ✓ Processed: SeaLake/SeaLake_2961.jpg
# ✓ Processed: SeaLake/SeaLake_2962.jpg
# ✓ Processed: SeaLake/SeaLake_2963.jpg
# ✓ Processed: SeaLake/SeaLake_2964.jpg
# ✓ Processed: SeaLake/SeaLake_2965.jpg
# ✓ Processed: SeaLake/SeaLake_2966.jpg
# ✓ Processed: SeaLake/SeaLake_2967.jpg
# ✓ Processed: SeaLake/SeaLake_2968.jpg
# ✓ Processed: SeaLake/SeaLake_2969.jpg
# ✓ Processed: SeaLake/SeaLake_2970.jpg
# ✓ Processed: SeaLake/SeaLake_2971.jpg
# ✓ Processed: SeaLake/SeaLake_2972.jpg
# ✓ Processed: SeaLake/SeaLake_2973.jpg
# ✓ Processed: SeaLake/SeaLake_2974.jpg
# ✓ Processed: SeaLake/SeaLake_2975.jpg
# ✓ Processed: SeaLake/SeaLake_2976.jpg
# ✓ Processed: SeaLake/SeaLake_2977.jpg
# ✓ Processed: SeaLake/SeaLake_2978.jpg
# ✓ Processed: SeaLake/SeaLake_2979.jpg
# ✓ Processed: SeaLake/SeaLake_2980.jpg
# ✓ Processed: SeaLake/SeaLake_2981.jpg
# ✓ Processed: SeaLake/SeaLake_2982.jpg
# ✓ Processed: SeaLake/SeaLake_2983.jpg
# ✓ Processed: SeaLake/SeaLake_2984.jpg
# ✓ Processed: SeaLake/SeaLake_2985.jpg
# ✓ Processed: SeaLake/SeaLake_2986.jpg
# ✓ Processed: SeaLake/SeaLake_2987.jpg
# ✓ Processed: SeaLake/SeaLake_2988.jpg
# ✓ Processed: SeaLake/SeaLake_2989.jpg
# ✓ Processed: SeaLake/SeaLake_2990.jpg
# ✓ Processed: SeaLake/SeaLake_2991.jpg
# ✓ Processed: SeaLake/SeaLake_2992.jpg
# ✓ Processed: SeaLake/SeaLake_2993.jpg
# ✓ Processed: SeaLake/SeaLake_2994.jpg
# ✓ Processed: SeaLake/SeaLake_2995.jpg
# ✓ Processed: SeaLake/SeaLake_2996.jpg
# ✓ Processed: SeaLake/SeaLake_2997.jpg
# ✓ Processed: SeaLake/SeaLake_2998.jpg
# ✓ Processed: SeaLake/SeaLake_2999.jpg
# ✓ Processed: SeaLake/SeaLake_3000.jpg
# ✅ All images processed.
